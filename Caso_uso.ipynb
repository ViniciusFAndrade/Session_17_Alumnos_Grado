# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stud=pd.read_csv("C:\\FCD\\PythonFundamental_Femsa\\clean_students_complete.csv")
stud
# Out:
#        Unnamed: 0  Student ID         student_name gender grade  \
# 0               0           0         Paul Bradley      M   9th
# 1               1           1         Victor Smith      M  12th
# 2               2           2      Kevin Rodriguez      M  12th
# 3               3           3        Richard Scott      M  12th
# 4               4           4           Bonnie Ray      F   9th
# 5               5           5        Bryan Miranda      M   9th
# 6               6           6        Sheena Carter      F  11th
# 7               7           7         Nicole Baker      F  12th
# 8               8           8         Michael Roth      M  10th
# 9               9           9       Matthew Greene      M  10th
# 10             10          10     Andrew Alexander      M  10th
# 11             11          11        Daniel Cooper      M  10th
# 12             12          12      Brittney Walker      F   9th
# 13             13          13         William Long      M   9th
# ...

# %%
stud.set_index("Student ID",inplace=True)

# %%
stud
# Out:
#             Unnamed: 0         student_name gender grade         school_name  \
# Student ID
# 0                    0         Paul Bradley      M   9th   Huang High School
# 1                    1         Victor Smith      M  12th   Huang High School
# 2                    2      Kevin Rodriguez      M  12th   Huang High School
# 3                    3        Richard Scott      M  12th   Huang High School
# 4                    4           Bonnie Ray      F   9th   Huang High School
# 5                    5        Bryan Miranda      M   9th   Huang High School
# 6                    6        Sheena Carter      F  11th   Huang High School
# 7                    7         Nicole Baker      F  12th   Huang High School
# 8                    8         Michael Roth      M  10th   Huang High School
# 9                    9       Matthew Greene      M  10th   Huang High School
# 10                  10     Andrew Alexander      M  10th   Huang High School
# ...

# %%
stud=stud.drop(["Unnamed: 0"],axis=1)
stud
# Out:
#                    student_name gender grade         school_name  \
# Student ID
# 0                  Paul Bradley      M   9th   Huang High School
# 1                  Victor Smith      M  12th   Huang High School
# 2               Kevin Rodriguez      M  12th   Huang High School
# 3                 Richard Scott      M  12th   Huang High School
# 4                    Bonnie Ray      F   9th   Huang High School
# 5                 Bryan Miranda      M   9th   Huang High School
# 6                 Sheena Carter      F  11th   Huang High School
# 7                  Nicole Baker      F  12th   Huang High School
# 8                  Michael Roth      M  10th   Huang High School
# 9                Matthew Greene      M  10th   Huang High School
# 10             Andrew Alexander      M  10th   Huang High School
# 11                Daniel Cooper      M  10th   Huang High School
# 12              Brittney Walker      F   9th   Huang High School
# ...

# %%
nomes=stud["grade"].unique()
nomes.tolist()
nomes
# Out:
# array(['9th', '12th', '11th', '10th'], dtype=object)

# %%
stud["grade"].value_counts().plot(kind="bar")
